# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Lendo os datasets de treino e teste

# %%
data_train = pd.read_csv('../../data/ElectricDemandForecasting-DL-master_data_hourly_20140102_20191101_train.csv', parse_dates=['datetime'])

# %%
data_train.head()
# Out:
#    value  percentage                   datetime
# 0  24256    0.340316  2014-01-02 00:00:00+01:00
# 1  24260    0.343019  2014-01-02 00:10:00+01:00
# 2  23689    0.340178  2014-01-02 00:20:00+01:00
# 3  23349    0.339301  2014-01-02 00:30:00+01:00
# 4  22896    0.337122  2014-01-02 00:40:00+01:00

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245376 entries, 0 to 245375
# Data columns (total 3 columns):
# value         245376 non-null int64
# percentage    245376 non-null float64
# datetime      245376 non-null object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 5.6+ MB

# %%
data_test = pd.read_csv('../../data/ElectricDemandForecasting-DL-master_data_hourly_20140102_20191101_test.csv', parse_dates=['datetime'])

# %%
data_test.head()
# Out:
#    value  percentage                   datetime
# 0  25392    0.336666  2018-09-02 01:00:00+02:00
# 1  25302    0.336830  2018-09-02 01:10:00+02:00
# 2  25122    0.336193  2018-09-02 01:20:00+02:00
# 3  24627    0.332721  2018-09-02 01:30:00+02:00
# 4  24488    0.332419  2018-09-02 01:40:00+02:00

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61343 entries, 0 to 61342
# Data columns (total 3 columns):
# value         61343 non-null int64
# percentage    61343 non-null float64
# datetime      61343 non-null object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.4+ MB

# %%
dataframe_completed = data_train.append(data_test) #Dataframe completo

# %%
dataframe.info()
dataframe.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306719 entries, 0 to 61342
# Data columns (total 3 columns):
# value         306719 non-null int64
# percentage    306719 non-null float64
# datetime      306719 non-null object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.4+ MB
#    value  percentage                   datetime
# 0  24256    0.340316  2014-01-02 00:00:00+01:00
# 1  24260    0.343019  2014-01-02 00:10:00+01:00
# 2  23689    0.340178  2014-01-02 00:20:00+01:00
# 3  23349    0.339301  2014-01-02 00:30:00+01:00
# 4  22896    0.337122  2014-01-02 00:40:00+01:00

# %%
## Análise Exploratória

# %%
dataframe.describe()
# Out:
#                value     percentage
# count  306719.000000  306719.000000
# mean    28510.900055       0.348009
# std      4571.666536       2.164797
# min     17714.000000       0.314323
# 25%     24620.000000       0.332337
# 50%     28729.000000       0.333546
# 75%     31991.500000       0.334795
# max     41217.000000     335.000000

# %%
data_train.plot(x='datetime',y='value', figsize=(50,10))

# %%
data_test.plot(x='datetime',y='percentage', figsize=(50,10))

# %%
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=200):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

# %%
plot_df(data_train, x=data_train.datetime, y=data_train.value, title="Electric series")
